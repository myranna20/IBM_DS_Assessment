# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Mirian Akwara
# I desire to be a Data Scientist

# %% [markdown]
# *I am interested in data science because I want to help businesses make smart decisions through indepth insight from Data.*

# %% [markdown]
# ### My code in cell 5  must execute and display the output of "1 + 1"

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# * bullet point
# * bullet point
# 1. Numbered list
# 2. Numbered list
#
# |Name||Age||Basic Salary|
# |----||----||----|
# |Mimi||20||500,000|
# |Ihu||21||200,000|
# |Aham||25||600,000|
#
# https://www.youtube.com/watch?v=tYtPOq3AkmM
#
# [Koolac](https://www.youtube.com/watch?v=tYtPOq3AkmM "Youtube link")
